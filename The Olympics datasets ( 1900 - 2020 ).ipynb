# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Desktop/قائمة الانجازات/athlete_events.csv')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
plt.figure(figsize=(9,4))
plt.title('number of medals over the Year')
df.Year.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:title={'center':'number of medals over the Year'}>

# %%
itemNames = df['Medal'].value_counts().index[:10]
itemValues = df['Medal'].value_counts().values[:10]
plt.figure(figsize=(20,9))
plt.ylabel('count', fontsize='medium')
plt.xlabel('Medal', fontsize='medium')
plt.title('Top 10 Medalies')
plt.bar(itemNames,itemValues, width = 0.7,color='purple',linewidth=0.4)
for i in range(len(itemNames)):
    plt.text(i,itemValues[i],itemValues[i],ha='center',va='bottom')
plt.show()

# %%
itemNames = df['City'].value_counts().index[:10]
itemValues = df['City'].value_counts().values[:10]
plt.figure(figsize=(20,9))
plt.ylabel('count', fontsize='medium')
plt.xlabel('City', fontsize='medium')
plt.title('Top 10 Cities')
plt.bar(itemNames,itemValues, width = 0.7,color='purple',linewidth=0.4)
for i in range(len(itemNames)):
    plt.text(i,itemValues[i],itemValues[i],ha='center',va='bottom')
plt.show()

# %%
itemNames = df['Sport'].value_counts().index[:10]
itemValues = df['Sport'].value_counts().values[:10]
plt.figure(figsize=(20,9))
plt.ylabel('count', fontsize='medium')
plt.xlabel('Sport', fontsize='medium')
plt.title('Top 10 Sportes')
plt.bar(itemNames,itemValues, width = 0.7,color='purple',linewidth=0.4)
for i in range(len(itemNames)):
    plt.text(i,itemValues[i],itemValues[i],ha='center',va='bottom')
plt.show()

# %%
labels = df.Sex.value_counts().index
colors = ['royalblue','orangered']
sex = df.Sex.value_counts().values
plt.figure(figsize = (5,5))
plt.pie(sex, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('proportion of Sexes',color = 'black',fontsize = 30)
# Out:
# Text(0.5, 1.0, 'proportion of Sexes')

# %%
female_df=df[df['Sex']== 'F']
female_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 4  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal
# 4    Speed Skating Women's 500 metres   NaN
# 5  Speed Skating Women's 1,000 metres   NaN
# ...

# %%
plt.figure(figsize=(9,4))
plt.title('female impact over the Years')
female_df.Year.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:title={'center':'female impact over the Years'}>

# %%
itemNames = df['Name'].value_counts().index[:8]
itemValues = df['Name'].value_counts().values[:8]
plt.figure(figsize=(20,9))
plt.ylabel('count', fontsize='medium')
plt.xlabel('Name', fontsize='medium')
plt.title('Top 10 Names')
plt.bar(itemNames,itemValues, width = 0.7,color='purple',linewidth=0.4)
for i in range(len(itemNames)):
    plt.text(i,itemValues[i],itemValues[i],ha='center',va='bottom')
plt.show()

# %%
df_gold=df[df['Medal']== 'Gold']
df_gold.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games  Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event Medal
# 3        Tug-Of-War Men's Tug-Of-War  Gold
# 42  Gymnastics Men's Team All-Around  Gold
# ...

# %%
df_silver=df[df['Medal']== 'Silver']
df_silver.head()
# Out:
#      ID                Name Sex   Age  Height  Weight         Team  NOC  \
# 63   20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway  NOR
# 67   20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway  NOR
# 86   25    Alf Lied Aanning   M  24.0     NaN     NaN       Norway  NOR
# 92   30    Pepijn Aardewijn   M  26.0   189.0    72.0  Netherlands  NED
# 106  38        Karl Jan Aas   M  20.0     NaN     NaN       Norway  NOR
#
#            Games  Year  Season         City          Sport  \
# 63   1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 67   1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 86   1920 Summer  1920  Summer    Antwerpen     Gymnastics
# 92   1996 Summer  1996  Summer      Atlanta         Rowing
# 106  1920 Summer  1920  Summer    Antwerpen     Gymnastics
#
#                                              Event   Medal
# 63                    Alpine Skiing Men's Downhill  Silver
# ...

# %%
df_bronze=df[df['Medal']== 'Bronze']
df_bronze.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight     Team  NOC  \
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN  Finland  FIN
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN  Finland  FIN
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 50  17   Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland  FIN
#
#           Games  Year  Season       City       Sport  \
# 37  1920 Summer  1920  Summer  Antwerpen    Swimming
# 38  1920 Summer  1920  Summer  Antwerpen    Swimming
# 40  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 41  1948 Summer  1948  Summer     London  Gymnastics
# 50  1952 Summer  1952  Summer   Helsinki  Gymnastics
#
#                                      Event   Medal
# 37  Swimming Men's 200 metres Breaststroke  Bronze
# 38  Swimming Men's 400 metres Breaststroke  Bronze
# ...

# %%
itemNames = df_gold['Name'].value_counts().index[:6]
itemValues = df_gold['Name'].value_counts().values[:6]
plt.figure(figsize=(20,9))
plt.ylabel('count', fontsize='medium')
plt.xlabel('Name', fontsize='medium')
plt.title('Top 10 Names')
plt.bar(itemNames,itemValues, width = 0.7,color='purple',linewidth=0.4)
for i in range(len(itemNames)):
    plt.text(i,itemValues[i],itemValues[i],ha='center',va='bottom')
plt.show()

# %%
itemNames = df_silver['Name'].value_counts().index[:6]
itemValues = df_silver['Name'].value_counts().values[:6]
plt.figure(figsize=(20,9))
plt.ylabel('count', fontsize='medium')
plt.xlabel('Name', fontsize='medium')
plt.title('Top 10 Names')
plt.bar(itemNames,itemValues, width = 0.7,color='purple',linewidth=0.4)
for i in range(len(itemNames)):
    plt.text(i,itemValues[i],itemValues[i],ha='center',va='bottom')
plt.show()

# %%
itemNames = df_bronze['Name'].value_counts().index[:6]
itemValues = df_bronze['Name'].value_counts().values[:6]
plt.figure(figsize=(20,9))
plt.ylabel('count', fontsize='medium')
plt.xlabel('Name', fontsize='medium')
plt.title('Top 10 Names')
plt.bar(itemNames,itemValues, width = 0.7,color='purple',linewidth=0.4)
for i in range(len(itemNames)):
    plt.text(i,itemValues[i],itemValues[i],ha='center',va='bottom')
plt.show()

# %% [markdown]
# ## Thank You
